# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/1_Basics/24_Pandas_Inspection.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Pandas Inspection

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# check the dataframes

# %% [markdown]
# Load in the data.

# %%
# Install datasets Library (if not already installed)
# !pip install -U datasets

# Importing Libraries
import pandas as pd
from datasets import load_dataset

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %% [markdown]
# ## View
#
# ### Notes
#
# - View the first rows of data in the DataFrame using `head()`.
# - View the last few rows of the DataFrame using `tail()`.
#
# These are used to get a quick view of the data frame. Good for exploratory analysis and understanding the data.
#
# ### Examples
#
# Let's look at the first few rows of our DataFrame using `head()` and `tail()`.

# %% [markdown]
# ### Head()
#
# Let's look at the DataFrame with `head()`.

# %%
df.head()
# Out:
#   job_title_short                job_title  \
# 0    Data Analyst           Data Analytics
# 1  Data Scientist    Data Scientist Intern
# 2    Data Analyst  Manager, Data Analytics
# 3   Data Engineer            Data Engineer
# 4    Data Analyst   Technical Data Analyst
#
#                                  job_location                   job_via  \
# 0               Monterrey, Nuevo Leon, Mexico                 via BeBee
# 1                            Lisbon, Portugal  via Empregos Trabajo.org
# 2  Guanacaste Province, Lagunilla, Costa Rica      via BeBee Costa Rica
# 3                            Lambayeque, Peru            via BeBee Perú
# 4                                 Fairfax, VA                via Indeed
#
#   job_schedule_type  job_work_from_home          search_location  \
# 0         Part-time               False                   Mexico
# 1         Full-time               False                 Portugal
# 2         Full-time               False               Costa Rica
# 3         Full-time               False                     Peru
# 4        Contractor               False  New York, United States
#
#        job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0  2023-12-05 07:26:05                  False                 False
# 1  2023-08-20 07:46:51                  False                 False
# 2  2023-11-21 08:37:14                  False                 False
# 3  2023-11-21 07:36:33                   True                 False
# 4  2023-12-20 07:00:10                   True                 False
#
#      job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0         Mexico        None              NaN              NaN
# 1       Portugal        None              NaN              NaN
# 2     Costa Rica        None              NaN              NaN
# 3           Peru        None              NaN              NaN
# 4  United States        None              NaN              NaN
#
#                             company_name  \
# 0  2U Bootcamps Instructional Engagement
# 1                                  Nokia
# 2               Thermo Fisher Scientific
# 3                                Emprego
# 4                       Info Origin Inc.
#
#                                           job_skills  \
# 0  ['go', 'python', 'mongodb', 'mongodb', 'css', ...
# 1  ['sql', 'python', 'sql server', 'oracle', 'azu...
# 2                                               None
# 3                                               None
# 4                          ['sql', 'python', 'jira']
#
#                                      job_type_skills
# 0  {'analyst_tools': ['tableau'], 'databases': ['...
# 1  {'analyst_tools': ['sap'], 'cloud': ['oracle',...
# 2                                               None
# 3                                               None
# 4  {'async': ['jira'], 'programming': ['sql', 'py...

# %% [markdown]
# You can also specify the number of rows you want to look at. Here we want to look at the first 10 rows using `head()`.

# %%
df.head(10)
# Out:
#          job_title_short                                          job_title  \
# 0           Data Analyst                                     Data Analytics
# 1         Data Scientist                              Data Scientist Intern
# 2           Data Analyst                            Manager, Data Analytics
# 3          Data Engineer                                      Data Engineer
# 4           Data Analyst                             Technical Data Analyst
# 5          Data Engineer                                      Data Engineer
# 6         Data Scientist               Research Data Scientist - Now Hiring
# 7         Data Scientist  Diversity and Inclusion Workforce Data Scienti...
# 8         Data Scientist                                     Data Scientist
# 9  Senior Data Scientist                               Big Data Senior Work
#
#                                  job_location                   job_via  \
# 0               Monterrey, Nuevo Leon, Mexico                 via BeBee
# 1                            Lisbon, Portugal  via Empregos Trabajo.org
# 2  Guanacaste Province, Lagunilla, Costa Rica      via BeBee Costa Rica
# 3                            Lambayeque, Peru            via BeBee Perú
# 4                                 Fairfax, VA                via Indeed
# 5            Abu Dhabi - United Arab Emirates              via LinkedIn
# 6                              Washington, DC              via Snagajob
# 7                               United States                 via BeBee
# 8                       Tel Aviv-Yafo, Israel  via Natural Intelligence
# 9               Monterrey, Nuevo Leon, Mexico          via BeBee México
#
#   job_schedule_type  job_work_from_home          search_location  \
# 0         Part-time               False                   Mexico
# 1         Full-time               False                 Portugal
# 2         Full-time               False               Costa Rica
# 3         Full-time               False                     Peru
# 4        Contractor               False  New York, United States
# 5        Contractor               False     United Arab Emirates
# 6         Full-time               False  New York, United States
# 7         Full-time               False     Texas, United States
# 8         Full-time               False                   Israel
# 9         Full-time               False                   Mexico
#
#        job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0  2023-12-05 07:26:05                  False                 False
# 1  2023-08-20 07:46:51                  False                 False
# 2  2023-11-21 08:37:14                  False                 False
# 3  2023-11-21 07:36:33                   True                 False
# 4  2023-12-20 07:00:10                   True                 False
# 5  2023-07-06 07:14:41                  False                 False
# 6  2023-02-01 07:03:49                  False                  True
# 7  2023-07-27 07:04:35                  False                 False
# 8  2023-05-05 07:41:03                  False                 False
# 9  2023-06-16 07:53:07                  False                 False
#
#             job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0                Mexico        None              NaN              NaN
# 1              Portugal        None              NaN              NaN
# 2            Costa Rica        None              NaN              NaN
# 3                  Peru        None              NaN              NaN
# 4         United States        None              NaN              NaN
# 5  United Arab Emirates        None              NaN              NaN
# 6         United States        None              NaN              NaN
# 7         United States        None              NaN              NaN
# 8                Israel        None              NaN              NaN
# 9                Mexico        None              NaN              NaN
#
#                             company_name  \
# 0  2U Bootcamps Instructional Engagement
# 1                                  Nokia
# 2               Thermo Fisher Scientific
# 3                                Emprego
# 4                       Info Origin Inc.
# 5               Alexander Ash Consulting
# 6                    Booz Allen Hamilton
# 7                              CIDIS LLC
# 8                   Natural Intelligence
# 9                              BairesDev
#
#                                           job_skills  \
# 0  ['go', 'python', 'mongodb', 'mongodb', 'css', ...
# 1  ['sql', 'python', 'sql server', 'oracle', 'azu...
# 2                                               None
# 3                                               None
# 4                          ['sql', 'python', 'jira']
# 5                ['sql', 'aws', 'snowflake', 'flow']
# 6     ['python', 'r', 'tableau', 'splunk', 'docker']
# 7  ['python', 'r', 'sql', 'cognos', 'alteryx', 't...
# 8                                               None
# 9  ['java', 'python', 'aws', 'spark', 'hadoop', '...
#
#                                      job_type_skills
# 0  {'analyst_tools': ['tableau'], 'databases': ['...
# 1  {'analyst_tools': ['sap'], 'cloud': ['oracle',...
# 2                                               None
# 3                                               None
# 4  {'async': ['jira'], 'programming': ['sql', 'py...
# 5  {'cloud': ['aws', 'snowflake'], 'other': ['flo...
# 6  {'analyst_tools': ['tableau', 'splunk'], 'othe...
# 7  {'analyst_tools': ['cognos', 'alteryx', 'table...
# 8                                               None
# 9  {'cloud': ['aws'], 'libraries': ['spark', 'had...

# %% [markdown]
# ### Tail()
#
# Now let's look at the last few rows using `tail()`.

# %%
df.tail()
# Out:
#              job_title_short  \
# 787681  Senior Data Engineer
# 787682          Data Analyst
# 787683         Data Engineer
# 787684     Software Engineer
# 787685  Senior Data Engineer
#
#                                                 job_title  \
# 787681  (Senior) Data Engineer (m/w/d) - PUBLIC BW / C...
# 787682                                  Lead Data Analyst
# 787683                                 Lead Data Engineer
# 787684                     Lead Solutions Design Engineer
# 787685                       Senior Data Engineer (m/f/d)
#
#                            job_location                     job_via  \
# 787681  Leinfelden-Echterdingen, Jerman          melalui Monster.de
# 787682                           Jerman   melalui BeBee Deutschland
# 787683        Frankfurt am Main, Jerman  melalui Top County Careers
# 787684            San Juan, Puerto Riko   melalui BeBee Puerto Rico
# 787685                Paderborn, Jerman  melalui Top County Careers
#
#        job_schedule_type  job_work_from_home search_location  \
# 787681   Pekerjaan tetap               False         Germany
# 787682   Pekerjaan tetap               False         Germany
# 787683   Pekerjaan tetap               False         Germany
# 787684   Pekerjaan tetap               False     Puerto Rico
# 787685   Pekerjaan tetap               False         Germany
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 787681  2023-03-13 06:18:59                  False                 False
# 787682  2023-03-12 06:18:18                  False                 False
# 787683  2023-03-13 06:18:59                  False                 False
# 787684  2023-03-12 06:31:19                  False                 False
# 787685  2023-03-13 06:19:07                  False                 False
#
#         job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 787681      Germany        None              NaN              NaN
# 787682      Germany        None              NaN              NaN
# 787683      Germany        None              NaN              NaN
# 787684  Puerto Rico        None              NaN              NaN
# 787685      Germany        None              NaN              NaN
#
#                   company_name  \
# 787681         CGI Group, Inc.
# 787682                  Amtrak
# 787683   Tiro Partners Limited
# 787684                   Ryder
# 787685  SO Digital Recruitment
#
#                                                job_skills  \
# 787681  ['python', 'sql', 'azure', 'aws', 'hadoop', 's...
# 787682  ['vba', 'sql', 'python', 'excel', 'sap', 'shar...
# 787683  ['python', 'sql', 'scala', 'java', 'javascript...
# 787684                 ['excel', 'powerpoint', 'tableau']
# 787685       ['sql', 'nosql', 'azure', 'spark', 'hadoop']
#
#                                           job_type_skills
# 787681  {'cloud': ['azure', 'aws'], 'libraries': ['had...
# 787682  {'analyst_tools': ['excel', 'sap', 'sharepoint...
# 787683  {'analyst_tools': ['sas', 'tableau', 'power bi...
# 787684  {'analyst_tools': ['excel', 'powerpoint', 'tab...
# 787685  {'cloud': ['azure'], 'libraries': ['spark', 'h...

# %% [markdown]
# Now let's look at the last 10 rows with `tail()`.

# %%
df.tail(10)
# Out:
#              job_title_short  \
# 787676         Data Engineer
# 787677        Data Scientist
# 787678         Data Engineer
# 787679         Data Engineer
# 787680         Data Engineer
# 787681  Senior Data Engineer
# 787682          Data Analyst
# 787683         Data Engineer
# 787684     Software Engineer
# 787685  Senior Data Engineer
#
#                                                 job_title  \
# 787676  Principal Associate, Data Engineer (Remote-Eli...
# 787677                                 Analytics Engineer
# 787678               Data Engineer Marketing Intelligence
# 787679                                Data engineer (H/F)
# 787680                                      Data Engineer
# 787681  (Senior) Data Engineer (m/w/d) - PUBLIC BW / C...
# 787682                                  Lead Data Analyst
# 787683                                 Lead Data Engineer
# 787684                     Lead Solutions Design Engineer
# 787685                       Senior Data Engineer (m/f/d)
#
#                                   job_location                     job_via  \
# 787676     Newark, New Jersey, Amerika Serikat         melalui Recruit.net
# 787677                                  Jerman        melalui Startup Jobs
# 787678                                  Jerman   melalui BeBee Deutschland
# 787679                           Jenewa, Swiss            melalui LinkedIn
# 787680  Overland Park, Kansas, Amerika Serikat            melalui LinkedIn
# 787681         Leinfelden-Echterdingen, Jerman          melalui Monster.de
# 787682                                  Jerman   melalui BeBee Deutschland
# 787683               Frankfurt am Main, Jerman  melalui Top County Careers
# 787684                   San Juan, Puerto Riko   melalui BeBee Puerto Rico
# 787685                       Paderborn, Jerman  melalui Top County Careers
#
#        job_schedule_type  job_work_from_home search_location  \
# 787676   Pekerjaan tetap               False           Sudan
# 787677   Pekerjaan tetap               False         Germany
# 787678   Pekerjaan tetap               False         Germany
# 787679   Pekerjaan tetap               False     Switzerland
# 787680   Pekerjaan tetap               False           Sudan
# 787681   Pekerjaan tetap               False         Germany
# 787682   Pekerjaan tetap               False         Germany
# 787683   Pekerjaan tetap               False         Germany
# 787684   Pekerjaan tetap               False     Puerto Rico
# 787685   Pekerjaan tetap               False         Germany
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 787676  2023-03-12 06:32:15                  False                 False
# 787677  2023-03-12 06:18:18                  False                 False
# 787678  2023-03-12 06:18:18                  False                 False
# 787679  2023-03-12 06:37:21                  False                 False
# 787680  2023-03-12 06:32:17                  False                 False
# 787681  2023-03-13 06:18:59                  False                 False
# 787682  2023-03-12 06:18:18                  False                 False
# 787683  2023-03-13 06:18:59                  False                 False
# 787684  2023-03-12 06:31:19                  False                 False
# 787685  2023-03-13 06:19:07                  False                 False
#
#         job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 787676        Sudan        None              NaN              NaN
# 787677      Germany        None              NaN              NaN
# 787678      Germany        None              NaN              NaN
# 787679  Switzerland        None              NaN              NaN
# 787680        Sudan        None              NaN              NaN
# 787681      Germany        None              NaN              NaN
# 787682      Germany        None              NaN              NaN
# 787683      Germany        None              NaN              NaN
# 787684  Puerto Rico        None              NaN              NaN
# 787685      Germany        None              NaN              NaN
#
#                         company_name  \
# 787676                   Capital One
# 787677                        Planet
# 787678  IU Internationale Hochschule
# 787679                         ROLEX
# 787680  Shamrock Trading Corporation
# 787681               CGI Group, Inc.
# 787682                        Amtrak
# 787683         Tiro Partners Limited
# 787684                         Ryder
# 787685        SO Digital Recruitment
#
#                                                job_skills  \
# 787676  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 787677  ['sql', 'bigquery', 'gdpr', 'git', 'gitlab', '...
# 787678                                               None
# 787679                         ['python', 'azure', 'git']
# 787680  ['nosql', 'mongodb', 'mongodb', 'python', 'ela...
# 787681  ['python', 'sql', 'azure', 'aws', 'hadoop', 's...
# 787682  ['vba', 'sql', 'python', 'excel', 'sap', 'shar...
# 787683  ['python', 'sql', 'scala', 'java', 'javascript...
# 787684                 ['excel', 'powerpoint', 'tableau']
# 787685       ['sql', 'nosql', 'azure', 'spark', 'hadoop']
#
#                                           job_type_skills
# 787676  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 787677  {'cloud': ['bigquery'], 'libraries': ['gdpr'],...
# 787678                                               None
# 787679  {'cloud': ['azure'], 'other': ['git'], 'progra...
# 787680  {'analyst_tools': ['excel'], 'cloud': ['aws', ...
# 787681  {'cloud': ['azure', 'aws'], 'libraries': ['had...
# 787682  {'analyst_tools': ['excel', 'sap', 'sharepoint...
# 787683  {'analyst_tools': ['sas', 'tableau', 'power bi...
# 787684  {'analyst_tools': ['excel', 'powerpoint', 'tab...
# 787685  {'cloud': ['azure'], 'libraries': ['spark', 'h...

# %% [markdown]
# ## Get Info
#
# ### Notes
#
# To get a concise summary for the DataFrame we'll be using `df.info`.
#
# This gives us:
# - Total number of entries
# - Number of columns
# - Column name
# - Count of non-null items in each column
# - Data type of each column
#
# Useful for exploring the data and getting a quick glance at the dataset.
#
# ### Example
#
# Use the `info()` on our DataFrame.
#
# **Note**: For our DataFrame the column `job_posted_date` isn't a datetime object but we'll fix this later.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 787686 entries, 0 to 787685
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        787686 non-null  object
#  1   job_title              787685 non-null  object
#  2   job_location           786646 non-null  object
#  3   job_via                787679 non-null  object
#  4   job_schedule_type      774976 non-null  object
#  5   job_work_from_home     787686 non-null  bool
#  6   search_location        787686 non-null  object
#  7   job_posted_date        787686 non-null  object
#  8   job_no_degree_mention  787686 non-null  bool
#  9   job_health_insurance   787686 non-null  bool
#  10  job_country            787633 non-null  object
#  11  salary_rate            33073 non-null   object
#  12  salary_year_avg        22026 non-null   float64
#  13  salary_hour_avg        10649 non-null   float64
#  14  company_name           787668 non-null  object
#  15  job_skills             670364 non-null  object
#  16  job_type_skills        670364 non-null  object
# dtypes: bool(3), float64(2), object(12)
# memory usage: 86.4+ MB

# %%
df.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22026.000000     10649.000000
# mean     123252.899602        47.009578
# std       48322.437693        21.871277
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.965000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
df['job_title_short'].unique()
# Out:
# array(['Data Analyst', 'Data Scientist', 'Data Engineer',
#        'Senior Data Scientist', 'Senior Data Engineer', 'Cloud Engineer',
#        'Business Analyst', 'Senior Data Analyst',
#        'Machine Learning Engineer', 'Software Engineer'], dtype=object)

# %% [markdown]
# But there are other ways to get an overview of the DataFrame. Like:
# - `len(df)` - Get length of DataFrame
# - `df.shape` - Get the (rows, columns)
# - `df.index` - Describe index
# - `df.columns` - Describe DataFrame columns
# - `df.count()` - Number of non-NA values
# - `df['column_name'].unique()` - The number of distinct values in a column

# %% [markdown]
# ## Accessing the Data

# %% [markdown]
# ### Variables (Columns)
#
# #### Notes
# - In dataframes columns are called variables.
# - To look at a specific column you could use `df['column_name']` or `df.column_name`.
# - Useful if you want to only look at a few columns in your dataframe, especially if your dataframe is particularly large.
#
# #### Example

# %%
df.job_title
# Out:
# 0                                            Data Analytics
# 1                                     Data Scientist Intern
# 2                                   Manager, Data Analytics
# 3                                             Data Engineer
# 4                                    Technical Data Analyst
#                                 ...
# 787681    (Senior) Data Engineer (m/w/d) - PUBLIC BW / C...
# 787682                                    Lead Data Analyst
# 787683                                   Lead Data Engineer
# 787684                       Lead Solutions Design Engineer
# 787685                         Senior Data Engineer (m/f/d)
# Name: job_title, Length: 787686, dtype: object

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# or
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# What if you want to look at several columns at once? Like you would with `SELECT column_name1, column_name2` in SQL? You can put list your column names within another bracket. Like this:
#
# ```python
# df[['column_name1', 'column_name2']]
# ```
#
# To look at `job_title` and `job_location` columns.

# %% [markdown]
# 🪲 **Debugging**
#
# **These are intentional mistakes**
#
# This is used to demonstrate debugging.
#
# Error: Forgot an end bracket `]`.
#
#
# ```python
# df[['job_title', 'job_location']
# ```
#
# Steps to Debug:
#
# 1. Look at the actual error, can you tell what the problem is?
# 2. If not, then look it up:
#   1. Use a chatbot like ChatGPT or Claude
#   2. Look it up using Google

# %%
df[['job_title', 'job_location']
# Out:
#   Cell In[21], line 1
#     df[['job_title', 'job_location']
#                                     ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# This is the correct code ✅.

# %%
df[['job_title', 'job_location']]
# Out:
#                                                 job_title  \
# 0           DevOps Engineer - Big Data/Advanced Analytics
# 1          Co-Op/Intern Software Engineer, Data Ingestion
# 2                                  Hybrid - Data Engineer
# 3                                          Data Scientist
# 4       Data Lead Engineer (with strong Python) - Remo...
# ...                                                   ...
# 787681                              Data Engineer (f/m/d)
# 787682                                  PreSales Engineer
# 787683                               Senior Data Engineer
# 787684                              Senior Sales Engineer
# 787685                           IT Business Analyst Data
#
#                                   job_location
# 0       Bari, Metropolitan City of Bari, Italy
# 1                        Vancouver, BC, Canada
# 2                                 New York, NY
# 3                                Hamtramck, MI
# 4                                     Anywhere
# ...                                        ...
# 787681                      Heidelberg, Jerman
# 787682                      Almaty, Kazakhstan
# 787683                          Berlin, Jerman
# 787684                           Jenewa, Swiss
# 787685                                  Jerman
#
# [787686 rows x 2 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# -should make it as a list
# ![image.png](data:image/png;base64,...)
# -read it as a tuple
# ![image.png](data:image/png;base64,...)
# to make strings as lists

# %% [markdown]
# ### Observations (Rows)
#
# #### Notes
#
# * In DataFrames rows are called observations.
# * To view rows by index you can use `iloc[]`.
#     * `iloc[]` has more capabilities which we will be going into later in the advanced section.
#
# #### Example
#
# Let's look at the second row, which has the index of 1 (remember indexes start at 0).

# %%
df.iloc[1]
# Out:
# job_title_short                                              Data Engineer
# job_title                   Co-Op/Intern Software Engineer, Data Ingestion
# job_location                                         Vancouver, BC, Canada
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                     Canada
# job_posted_date                                        2023-05-05 18:37:58
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                         Canada
# salary_rate                                                            NaN
# salary_year_avg                                                        NaN
# salary_hour_avg                                                        NaN
# company_name                                                       Kinaxis
# job_skills               ['java', 'c#', 'mysql', 'oracle', 'docker', 'k...
# job_type_skills          {'cloud': ['oracle'], 'databases': ['mysql'], ...
# Name: 1, dtype: object

# %% [markdown]
# Is this correct? Let's use `df.head()` to look at the first 5 rows and confirm that the second row (with index 1) is correct.

# %%
df.head()
# Out:
#   job_title_short                                          job_title  \
# 0   Data Engineer      DevOps Engineer - Big Data/Advanced Analytics
# 1   Data Engineer     Co-Op/Intern Software Engineer, Data Ingestion
# 2   Data Engineer                             Hybrid - Data Engineer
# 3  Data Scientist                                     Data Scientist
# 4   Data Engineer  Data Lead Engineer (with strong Python) - Remo...
#
#                              job_location        job_via job_schedule_type  \
# 0  Bari, Metropolitan City of Bari, Italy   via LinkedIn         Full-time
# 1                   Vancouver, BC, Canada   via LinkedIn         Full-time
# 2                            New York, NY   via LinkedIn         Full-time
# 3                           Hamtramck, MI      via BeBee         Full-time
# 4                                Anywhere  via Jobgether         Full-time
#
#    job_work_from_home          search_location      job_posted_date  \
# 0               False                    Italy  2023-10-24 18:16:15
# 1               False                   Canada  2023-05-05 18:37:58
# 2               False                    Sudan  2023-07-25 19:07:08
# 3               False  Illinois, United States  2023-11-30 18:05:20
# 4                True                   Panama  2023-08-13 18:32:30
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                   True                 False          Italy         NaN
# 1                  False                 False         Canada         NaN
# 2                  False                 False          Sudan        year
# 3                  False                 False  United States         NaN
# 4                  False                 False         Panama         NaN
#
#    salary_year_avg  salary_hour_avg       company_name  \
# 0              NaN              NaN    NTT DATA Italia
# 1              NaN              NaN            Kinaxis
# 2         425000.0              NaN  Durlston Partners
# 3              NaN              NaN             Apexon
# 4              NaN              NaN     FullStack Labs
#
#                                           job_skills  \
# 0  ['shell', 'python', 'bash', 'mongodb', 'mongod...
# 1  ['java', 'c#', 'mysql', 'oracle', 'docker', 'k...
# 2                                         ['python']
# 3  ['sql', 'r', 'scala', 'java', 'gcp', 'aws', 'h...
# 4  ['python', 'aws', 'tableau', 'looker', 'terraf...
#
#                                      job_type_skills
# 0  {'cloud': ['gcp', 'aws', 'azure'], 'databases'...
# 1  {'cloud': ['oracle'], 'databases': ['mysql'], ...
# 2                        {'programming': ['python']}
# 3  {'analyst_tools': ['tableau', 'sap', 'word'], ...
# 4  {'analyst_tools': ['tableau', 'looker'], 'asyn...

# %% [markdown]
# To look at more than one row at once we can use `iloc[]` with more than one index listed. So to look at the 2nd - 5th row (index 1 to 4). We need to use `[2:5]`. The second index number is not inclusive. So this lists index: 2, 3, and 4. Excluding index 5.

# %%
df.iloc[2:5]
# Out:
#   job_title_short                                          job_title  \
# 2   Data Engineer                             Hybrid - Data Engineer
# 3  Data Scientist                                     Data Scientist
# 4   Data Engineer  Data Lead Engineer (with strong Python) - Remo...
#
#     job_location        job_via job_schedule_type  job_work_from_home  \
# 2   New York, NY   via LinkedIn         Full-time               False
# 3  Hamtramck, MI      via BeBee         Full-time               False
# 4       Anywhere  via Jobgether         Full-time                True
#
#            search_location      job_posted_date  job_no_degree_mention  \
# 2                    Sudan  2023-07-25 19:07:08                  False
# 3  Illinois, United States  2023-11-30 18:05:20                  False
# 4                   Panama  2023-08-13 18:32:30                  False
#
#    job_health_insurance    job_country salary_rate  salary_year_avg  \
# 2                 False          Sudan        year         425000.0
# 3                 False  United States         NaN              NaN
# 4                 False         Panama         NaN              NaN
#
#    salary_hour_avg       company_name  \
# 2              NaN  Durlston Partners
# 3              NaN             Apexon
# 4              NaN     FullStack Labs
#
#                                           job_skills  \
# 2                                         ['python']
# 3  ['sql', 'r', 'scala', 'java', 'gcp', 'aws', 'h...
# 4  ['python', 'aws', 'tableau', 'looker', 'terraf...
#
#                                      job_type_skills
# 2                        {'programming': ['python']}
# 3  {'analyst_tools': ['tableau', 'sap', 'word'], ...
# 4  {'analyst_tools': ['tableau', 'looker'], 'asyn...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Filtering Rows
#
# ##### Notes
#
# * You can also filter by rows by applying a condition inside brackets `[]`.
# * With this syntax: `df[df['column_name'] > value]`.
#     * The `>` can be any conditional operator like: `>`, `<`, `==`, etc.
#
# ##### Example
#
# Let's only return rows that have an `salary_year_avg` greater than 100000.

# %% [markdown]
# 🪲 **Debugging**
#
# **These are intentional mistakes**
#
# This is used to demonstrate debugging.
#
# Error: End bracket `]` is in the correct location.
#
# ```python
# df[df['salary_year_avg']] > 100000
# ```
#
# Steps to Debug:
#
# 1. Look at the actual error, can you tell what the problem is?
# 2. If not, then look it up:
#   1. Use a chatbot like ChatGPT or Claude
#   2. Look it up using Google

# %%
df[df['salary_year_avg']] > 100000
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df[df['salary_year_avg']] > 100000
#
# File c:\Users\SaderPC\anaconda3\envs\venv1\Lib\site-packages\pandas\core\frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
#    4095         key = list(key)
# -> 4096     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4098 # take() does not accept boolean indexers
#    4099 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\SaderPC\anaconda3\envs\venv1\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\SaderPC\anaconda3\envs\venv1\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([     nan,      nan, 425000.0,      nan,      nan,      nan, 180000.0,\n            nan,      nan,      nan,\n       ...\n            nan,      nan,      nan,      nan,      nan,      nan,      nan,\n            nan,      nan,      nan],\n      dtype='float64', length=787686)] are in the [columns]"

# %% [markdown]
# This is the correct code ✅.

# %%
df[df['salary_year_avg'] > 100000]
# Out:
#              job_title_short                             job_title  \
# 56             Data Engineer                         Data Engineer
# 76              Data Analyst                          Data Analyst
# 79             Data Engineer                         Data Engineer
# 262            Data Engineer           Data Engineer with Mulesoft
# 288             Data Analyst             Mid-Level Data BI Analyst
# ...                      ...                                   ...
# 787368         Data Engineer  Data Engineer / DBA - TS/SCI w/ Poly
# 787496          Data Analyst       Lead Credit Bureau Data Analyst
# 787497  Senior Data Engineer                  Senior Data Engineer
# 787505         Data Engineer         Data Engineer / San Francisco
# 787513         Data Engineer                    Big Data Developer
#
#                job_location                 job_via job_schedule_type  \
# 56                 Anywhere            via EchoJobs         Full-time
# 76                   France         via Ai-Jobs.net         Full-time
# 79                 Orem, UT             via Ladders         Full-time
# 262                Anywhere  via Motion Recruitment         Full-time
# 288                Anywhere        via ZipRecruiter         Full-time
# ...                     ...                     ...               ...
# 787368         Bethesda, MD             via Ladders         Full-time
# 787496      Des Plaines, IL             via Ladders         Full-time
# 787497    San Francisco, CA         via Ai-Jobs.net         Full-time
# 787505    San Francisco, CA  via Motion Recruitment         Full-time
# 787513  Toronto, ON, Canada             via Ladders         Full-time
#
#         job_work_from_home            search_location      job_posted_date  \
# 56                    True    New York, United States  2023-01-08 07:04:55
# 76                   False                     France  2023-02-09 07:31:16
# 79                   False    Illinois, United States  2023-04-08 07:05:56
# 262                   True       Texas, United States  2023-09-20 07:06:21
# 288                   True     Florida, United States  2023-07-17 07:03:43
# ...                    ...                        ...                  ...
# 787368               False                    Georgia  2023-07-08 06:44:50
# 787496               False    Illinois, United States  2023-06-02 06:02:06
# 787497               False  California, United States  2023-06-28 06:04:16
# 787505               False                      Sudan  2023-04-12 06:59:59
# 787513               False                     Canada  2023-04-18 06:14:58
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 56                      False                  True  United States
# 76                      False                 False         France
# 79                      False                 False  United States
# 262                     False                  True  United States
# 288                     False                  True  United States
# ...                       ...                   ...            ...
# 787368                  False                 False  United States
# 787496                  False                  True  United States
# 787497                  False                  True  United States
# 787505                  False                 False          Sudan
# 787513                  False                 False         Canada
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 56            year         120000.0              NaN
# 76            year         111175.0              NaN
# 79            year         125000.0              NaN
# 262           year         127500.0              NaN
# 288           year         150000.0              NaN
# ...            ...              ...              ...
# 787368        year         125000.0              NaN
# 787496        year         115000.0              NaN
# 787497        year         147500.0              NaN
# 787505        year         145000.0              NaN
# 787513        year         175000.0              NaN
#
#                        company_name  \
# 56                  BioIntelliSense
# 76                    Contentsquare
# 79           Avetta (formerly PICS)
# 262              Motion Recruitment
# 288           Patterned Learning AI
# ...                             ...
# 787368           CACI International
# 787496  Discover Financial Services
# 787497                       Kikoff
# 787505           Motion Recruitment
# 787513                     CGI Inc.
#
#                                                job_skills  \
# 56      ['sql', 'python', 'databricks', 'spark', 'airf...
# 76              ['sql', 'python', 'snowflake', 'tableau']
# 79      ['sql', 'go', 'sql server', 'snowflake', 'reds...
# 262     ['python', 'sql', 'java', 'scala', 'nosql', 'a...
# 288     ['nosql', 'sql', 'vba', 'oracle', 'hadoop', 'e...
# ...                                                   ...
# 787368      ['sql', 'postgresql', 'aws', 'aurora', 'sap']
# 787496                                           ['unix']
# 787497             ['nosql', 'python', 'hadoop', 'spark']
# 787505  ['python', 'sql', 'mongodb', 'mongodb', 'aws',...
# 787513  ['java', 'c', 'c++', 'scala', 'shell', 'python...
#
#                                           job_type_skills
# 56      {'cloud': ['databricks'], 'libraries': ['spark...
# 76      {'analyst_tools': ['tableau'], 'cloud': ['snow...
# 79      {'analyst_tools': ['excel'], 'async': ['jira']...
# 262     {'cloud': ['aws', 'azure', 'redshift', 'bigque...
# 288     {'analyst_tools': ['excel', 'tableau'], 'cloud...
# ...                                                   ...
# 787368  {'analyst_tools': ['sap'], 'cloud': ['aws', 'a...
# 787496                                   {'os': ['unix']}
# 787497  {'libraries': ['hadoop', 'spark'], 'programmin...
# 787505  {'cloud': ['aws', 'gcp'], 'databases': ['mongo...
# 787513  {'cloud': ['oracle'], 'databases': ['db2', 'my...
#
# [13952 rows x 17 columns]

# %% [markdown]
# What if I only wanted to look at rows where the job title (`job_title_short`) is 'Business Analyst'?

# %%
df[df['job_title_short'] == 'Business Analyst']
# Out:
#          job_title_short                                   job_title  \
# 55      Business Analyst              Business Analyst at Lipa Later
# 68      Business Analyst                            Business Analyst
# 89      Business Analyst                                     Analyst
# 100     Business Analyst               Business Intelligence Analyst
# 102     Business Analyst                       Trade Auditor Analyst
# ...                  ...                                         ...
# 787625  Business Analyst                        Junior Sales Analyst
# 787635  Business Analyst               Senior Performance QA Analyst
# 787661  Business Analyst  Business Analytics Training and Internship
# 787670  Business Analyst                       Senior Sales Engineer
# 787671  Business Analyst                    IT Business Analyst Data
#
#                                              job_location  \
# 55                                         Nairobi, Kenya
# 68                                                  Spain
# 89                           Dubai - United Arab Emirates
# 100                                     Stockholm, Sweden
# 102                                           Philippines
# ...                                                   ...
# 787625  Kuala Lumpur, Federal Territory of Kuala Lumpu...
# 787635                                              India
# 787661                                             Jerman
# 787670                                      Jenewa, Swiss
# 787671                                             Jerman
#
#                       job_via job_schedule_type  job_work_from_home  \
# 55            via BeBee Kenya         Full-time               False
# 68                  via BeBee        Contractor               False
# 89                  via BeBee         Full-time               False
# 100           via Trabajo.org         Full-time               False
# 102                 via BeBee              None               False
# ...                       ...               ...                 ...
# 787625        via Trabajo.org         Full-time               False
# 787635    melalui BeBee India   Pekerjaan tetap               False
# 787661       melalui LinkedIn              None               False
# 787670  melalui BeBee Schweiz   Pekerjaan tetap               False
# 787671         melalui Indeed   Pekerjaan tetap               False
#
#              search_location      job_posted_date  job_no_degree_mention  \
# 55                     Kenya  2023-01-31 07:58:54                  False
# 68                     Spain  2023-07-26 07:45:41                  False
# 89      United Arab Emirates  2023-08-20 07:47:45                  False
# 100                   Sweden  2023-07-30 08:15:22                   True
# 102              Philippines  2023-08-27 07:13:44                   True
# ...                      ...                  ...                    ...
# 787625              Malaysia  2023-11-17 06:20:55                   True
# 787635                 India  2023-03-13 06:16:28                  False
# 787661               Germany  2023-03-12 06:18:18                  False
# 787670           Switzerland  2023-03-12 06:37:25                  False
# 787671               Germany  2023-03-12 06:18:18                  False
#
#         job_health_insurance           job_country salary_rate  \
# 55                     False                 Kenya        None
# 68                     False                 Spain        None
# 89                     False  United Arab Emirates        None
# 100                    False                Sweden        None
# 102                    False           Philippines        None
# ...                      ...                   ...         ...
# 787625                 False              Malaysia        None
# 787635                 False                 India        None
# 787661                 False               Germany        None
# 787670                 False           Switzerland        None
# 787671                 False               Germany        None
#
#         salary_year_avg  salary_hour_avg                   company_name  \
# 55                  NaN              NaN                     Lipa Later
# 68                  NaN              NaN               Broster Buchanan
# 89                  NaN              NaN  ZC CONSULTING, UNIPESSOAL LDA
# 100                 NaN              NaN                         Quinyx
# 102                 NaN              NaN         SGS (Malaysia) Sdn Bhd
# ...                 ...              ...                            ...
# 787625              NaN              NaN                       Noventiq
# 787635              NaN              NaN                Diebold Nixdorf
# 787661              NaN              NaN                          OESON
# 787670              NaN              NaN                      Snowflake
# 787671              NaN              NaN                         Raisin
#
#                                                job_skills  \
# 55                        ['python', 'r', 'sql', 'excel']
# 68                                                   None
# 89                                                   None
# 100     ['sql', 'python', 'redshift', 'tableau', 'look...
# 102                                                  None
# ...                                                   ...
# 787625                              ['excel', 'power bi']
# 787635                                               None
# 787661                                         ['python']
# 787670                      ['sql', 'snowflake', 'excel']
# 787671  ['sql', 'python', 'aws', 'looker', 'tableau', ...
#
#                                           job_type_skills
# 55      {'analyst_tools': ['excel'], 'programming': ['...
# 68                                                   None
# 89                                                   None
# 100     {'analyst_tools': ['tableau', 'looker', 'excel...
# 102                                                  None
# ...                                                   ...
# 787625           {'analyst_tools': ['excel', 'power bi']}
# 787635                                               None
# 787661                        {'programming': ['python']}
# 787670  {'analyst_tools': ['excel'], 'cloud': ['snowfl...
# 787671  {'analyst_tools': ['looker', 'tableau', 'splun...
#
# [49160 rows x 17 columns]

# %% [markdown]
# ## Find Not NA Values
#
# ### Notes
#
# * `pd.notna()` - displays if the values are not NA (missing values).
# * It returns a Boolean same-sized object indicating if the values are not NA.
#     * Non-missing values are `True`
#     * Missing values are `False`
# * Good for data preprocessing to remove or fill missing values, or to make decisions based on the presence of data.
#
# ### Example
#
# Let's only get rows where it has a yearly salary listed. Meaning that `salary_year_avg` is not null.

# %%
df[df['salary_year_avg'].notna()]
# Out:
#              job_title_short  \
# 18            Data Scientist
# 45            Data Scientist
# 56             Data Engineer
# 76              Data Analyst
# 79             Data Engineer
# ...                      ...
# 787368         Data Engineer
# 787496          Data Analyst
# 787497  Senior Data Engineer
# 787505         Data Engineer
# 787513         Data Engineer
#
#                                                 job_title  \
# 18      GapYear im Bereich Digital Transformation und ...
# 45                 Data Scientist with Security Clearance
# 56                                          Data Engineer
# 76                                           Data Analyst
# 79                                          Data Engineer
# ...                                                   ...
# 787368               Data Engineer / DBA - TS/SCI w/ Poly
# 787496                    Lead Credit Bureau Data Analyst
# 787497                               Senior Data Engineer
# 787505                      Data Engineer / San Francisco
# 787513                                 Big Data Developer
#
#                job_location                 job_via job_schedule_type  \
# 18      Immenstadt, Germany         via Ai-Jobs.net         Full-time
# 45          Springfield, MO               via BeBee         Full-time
# 56                 Anywhere            via EchoJobs         Full-time
# 76                   France         via Ai-Jobs.net         Full-time
# 79                 Orem, UT             via Ladders         Full-time
# ...                     ...                     ...               ...
# 787368         Bethesda, MD             via Ladders         Full-time
# 787496      Des Plaines, IL             via Ladders         Full-time
# 787497    San Francisco, CA         via Ai-Jobs.net         Full-time
# 787505    San Francisco, CA  via Motion Recruitment         Full-time
# 787513  Toronto, ON, Canada             via Ladders         Full-time
#
#         job_work_from_home            search_location      job_posted_date  \
# 18                   False                    Germany  2023-07-06 07:11:32
# 45                   False       Texas, United States  2023-12-29 07:02:14
# 56                    True    New York, United States  2023-01-08 07:04:55
# 76                   False                     France  2023-02-09 07:31:16
# 79                   False    Illinois, United States  2023-04-08 07:05:56
# ...                    ...                        ...                  ...
# 787368               False                    Georgia  2023-07-08 06:44:50
# 787496               False    Illinois, United States  2023-06-02 06:02:06
# 787497               False  California, United States  2023-06-28 06:04:16
# 787505               False                      Sudan  2023-04-12 06:59:59
# 787513               False                     Canada  2023-04-18 06:14:58
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 18                      False                 False        Germany
# 45                      False                 False  United States
# 56                      False                  True  United States
# 76                      False                 False         France
# 79                      False                 False  United States
# ...                       ...                   ...            ...
# 787368                  False                 False  United States
# 787496                  False                  True  United States
# 787497                  False                  True  United States
# 787505                  False                 False          Sudan
# 787513                  False                 False         Canada
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 18            year          56700.0              NaN
# 45            year         100000.0              NaN
# 56            year         120000.0              NaN
# 76            year         111175.0              NaN
# 79            year         125000.0              NaN
# ...            ...              ...              ...
# 787368        year         125000.0              NaN
# 787496        year         115000.0              NaN
# 787497        year         147500.0              NaN
# 787505        year         145000.0              NaN
# 787513        year         175000.0              NaN
#
#                        company_name  \
# 18                      Bosch Group
# 45                   Blackspoke LLC
# 56                  BioIntelliSense
# 76                    Contentsquare
# 79           Avetta (formerly PICS)
# ...                             ...
# 787368           CACI International
# 787496  Discover Financial Services
# 787497                       Kikoff
# 787505           Motion Recruitment
# 787513                     CGI Inc.
#
#                                                job_skills  \
# 18      ['sql', 'python', 'vba', 'oracle', 'power bi',...
# 45      ['python', 'c++', 'julia', 'go', 'r', 'aws', '...
# 56      ['sql', 'python', 'databricks', 'spark', 'airf...
# 76              ['sql', 'python', 'snowflake', 'tableau']
# 79      ['sql', 'go', 'sql server', 'snowflake', 'reds...
# ...                                                   ...
# 787368      ['sql', 'postgresql', 'aws', 'aurora', 'sap']
# 787496                                           ['unix']
# 787497             ['nosql', 'python', 'hadoop', 'spark']
# 787505  ['python', 'sql', 'mongodb', 'mongodb', 'aws',...
# 787513  ['java', 'c', 'c++', 'scala', 'shell', 'python...
#
#                                           job_type_skills
# 18      {'analyst_tools': ['power bi', 'excel'], 'clou...
# 45      {'cloud': ['aws', 'gcp'], 'libraries': ['tenso...
# 56      {'cloud': ['databricks'], 'libraries': ['spark...
# 76      {'analyst_tools': ['tableau'], 'cloud': ['snow...
# 79      {'analyst_tools': ['excel'], 'async': ['jira']...
# ...                                                   ...
# 787368  {'analyst_tools': ['sap'], 'cloud': ['aws', 'a...
# 787496                                   {'os': ['unix']}
# 787497  {'libraries': ['hadoop', 'spark'], 'programmin...
# 787505  {'cloud': ['aws', 'gcp'], 'databases': ['mongo...
# 787513  {'cloud': ['oracle'], 'databases': ['db2', 'my...
#
# [22026 rows x 17 columns]

# %% [markdown]
# You can apply this to multiple columns as well. Only return rows where the columns: `salary_year_avg` and `job_skills` are not null.

# %%
df[df[['salary_year_avg', 'job_skills']].notna().all(axis=1)]
# Out:
#              job_title_short  \
# 18            Data Scientist
# 45            Data Scientist
# 56             Data Engineer
# 76              Data Analyst
# 79             Data Engineer
# ...                      ...
# 787368         Data Engineer
# 787496          Data Analyst
# 787497  Senior Data Engineer
# 787505         Data Engineer
# 787513         Data Engineer
#
#                                                 job_title  \
# 18      GapYear im Bereich Digital Transformation und ...
# 45                 Data Scientist with Security Clearance
# 56                                          Data Engineer
# 76                                           Data Analyst
# 79                                          Data Engineer
# ...                                                   ...
# 787368               Data Engineer / DBA - TS/SCI w/ Poly
# 787496                    Lead Credit Bureau Data Analyst
# 787497                               Senior Data Engineer
# 787505                      Data Engineer / San Francisco
# 787513                                 Big Data Developer
#
#                job_location                 job_via job_schedule_type  \
# 18      Immenstadt, Germany         via Ai-Jobs.net         Full-time
# 45          Springfield, MO               via BeBee         Full-time
# 56                 Anywhere            via EchoJobs         Full-time
# 76                   France         via Ai-Jobs.net         Full-time
# 79                 Orem, UT             via Ladders         Full-time
# ...                     ...                     ...               ...
# 787368         Bethesda, MD             via Ladders         Full-time
# 787496      Des Plaines, IL             via Ladders         Full-time
# 787497    San Francisco, CA         via Ai-Jobs.net         Full-time
# 787505    San Francisco, CA  via Motion Recruitment         Full-time
# 787513  Toronto, ON, Canada             via Ladders         Full-time
#
#         job_work_from_home            search_location      job_posted_date  \
# 18                   False                    Germany  2023-07-06 07:11:32
# 45                   False       Texas, United States  2023-12-29 07:02:14
# 56                    True    New York, United States  2023-01-08 07:04:55
# 76                   False                     France  2023-02-09 07:31:16
# 79                   False    Illinois, United States  2023-04-08 07:05:56
# ...                    ...                        ...                  ...
# 787368               False                    Georgia  2023-07-08 06:44:50
# 787496               False    Illinois, United States  2023-06-02 06:02:06
# 787497               False  California, United States  2023-06-28 06:04:16
# 787505               False                      Sudan  2023-04-12 06:59:59
# 787513               False                     Canada  2023-04-18 06:14:58
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 18                      False                 False        Germany
# 45                      False                 False  United States
# 56                      False                  True  United States
# 76                      False                 False         France
# 79                      False                 False  United States
# ...                       ...                   ...            ...
# 787368                  False                 False  United States
# 787496                  False                  True  United States
# 787497                  False                  True  United States
# 787505                  False                 False          Sudan
# 787513                  False                 False         Canada
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 18            year          56700.0              NaN
# 45            year         100000.0              NaN
# 56            year         120000.0              NaN
# 76            year         111175.0              NaN
# 79            year         125000.0              NaN
# ...            ...              ...              ...
# 787368        year         125000.0              NaN
# 787496        year         115000.0              NaN
# 787497        year         147500.0              NaN
# 787505        year         145000.0              NaN
# 787513        year         175000.0              NaN
#
#                        company_name  \
# 18                      Bosch Group
# 45                   Blackspoke LLC
# 56                  BioIntelliSense
# 76                    Contentsquare
# 79           Avetta (formerly PICS)
# ...                             ...
# 787368           CACI International
# 787496  Discover Financial Services
# 787497                       Kikoff
# 787505           Motion Recruitment
# 787513                     CGI Inc.
#
#                                                job_skills  \
# 18      ['sql', 'python', 'vba', 'oracle', 'power bi',...
# 45      ['python', 'c++', 'julia', 'go', 'r', 'aws', '...
# 56      ['sql', 'python', 'databricks', 'spark', 'airf...
# 76              ['sql', 'python', 'snowflake', 'tableau']
# 79      ['sql', 'go', 'sql server', 'snowflake', 'reds...
# ...                                                   ...
# 787368      ['sql', 'postgresql', 'aws', 'aurora', 'sap']
# 787496                                           ['unix']
# 787497             ['nosql', 'python', 'hadoop', 'spark']
# 787505  ['python', 'sql', 'mongodb', 'mongodb', 'aws',...
# 787513  ['java', 'c', 'c++', 'scala', 'shell', 'python...
#
#                                           job_type_skills
# 18      {'analyst_tools': ['power bi', 'excel'], 'clou...
# 45      {'cloud': ['aws', 'gcp'], 'libraries': ['tenso...
# 56      {'cloud': ['databricks'], 'libraries': ['spark...
# 76      {'analyst_tools': ['tableau'], 'cloud': ['snow...
# 79      {'analyst_tools': ['excel'], 'async': ['jira']...
# ...                                                   ...
# 787368  {'analyst_tools': ['sap'], 'cloud': ['aws', 'a...
# 787496                                   {'os': ['unix']}
# 787497  {'libraries': ['hadoop', 'spark'], 'programmin...
# 787505  {'cloud': ['aws', 'gcp'], 'databases': ['mongo...
# 787513  {'cloud': ['oracle'], 'databases': ['db2', 'my...
#
# [20193 rows x 17 columns]

# %% [markdown]
# And you can apply this to the entire DataFrame to get a boolean DataFrame indicating where values aren't missing.

# %%
df.notna()
# Out:
#         job_title_short  job_title  job_location  job_via  job_schedule_type  \
# 0                  True       True          True     True               True
# 1                  True       True          True     True               True
# 2                  True       True          True     True               True
# 3                  True       True          True     True               True
# 4                  True       True          True     True               True
# ...                 ...        ...           ...      ...                ...
# 787681             True       True          True     True               True
# 787682             True       True          True     True               True
# 787683             True       True          True     True               True
# 787684             True       True          True     True               True
# 787685             True       True          True     True               True
#
#         job_work_from_home  search_location  job_posted_date  \
# 0                     True             True             True
# 1                     True             True             True
# 2                     True             True             True
# 3                     True             True             True
# 4                     True             True             True
# ...                    ...              ...              ...
# 787681                True             True             True
# 787682                True             True             True
# 787683                True             True             True
# 787684                True             True             True
# 787685                True             True             True
#
#         job_no_degree_mention  job_health_insurance  job_country  salary_rate  \
# 0                        True                  True         True        False
# 1                        True                  True         True        False
# 2                        True                  True         True        False
# 3                        True                  True         True        False
# 4                        True                  True         True        False
# ...                       ...                   ...          ...          ...
# 787681                   True                  True         True        False
# 787682                   True                  True         True        False
# 787683                   True                  True         True        False
# 787684                   True                  True         True        False
# 787685                   True                  True         True        False
#
#         salary_year_avg  salary_hour_avg  company_name  job_skills  \
# 0                 False            False          True        True
# 1                 False            False          True        True
# 2                 False            False          True       False
# 3                 False            False          True       False
# 4                 False            False          True        True
# ...                 ...              ...           ...         ...
# 787681            False            False          True        True
# 787682            False            False          True        True
# 787683            False            False          True        True
# 787684            False            False          True        True
# 787685            False            False          True        True
#
#         job_type_skills
# 0                  True
# 1                  True
# 2                 False
# 3                 False
# 4                  True
# ...                 ...
# 787681             True
# 787682             True
# 787683             True
# 787684             True
# 787685             True
#
# [787686 rows x 17 columns]
